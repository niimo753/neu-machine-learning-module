# %% [markdown]
# __HOMEWORK 10: DECISION TREE__
#
# Full name: Nguyễn Thị Minh Ngọc
# <br>
# Studet ID: 11219280
# <br>
# Class: DSEB 63

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# %% [markdown]
# # Problem 4

# %%
data = pd.read_csv("Data/diabetes.csv")
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
# split the dataset
X_train, X_test, y_train, y_test = train_test_split(data.iloc[:, :-1], data.iloc[:, -1], test_size=0.1, random_state=42)

# define the classifer
dtree = DecisionTreeClassifier(criterion="entropy")

# fit the data
dtree.fit(X_train, y_train)

# prediction
y_pred = dtree.predict(X_test)

# accuracy score
print("Accuracy for test set:", accuracy_score(y_test, y_pred))
print("Accuracy for train set:", accuracy_score(y_train, dtree.predict(X_train)))
# Out:
# Accuracy for test set: 0.8051948051948052
# Accuracy for train set: 1.0

# %%
fig, ax = plt.subplots(figsize=(20, 20))
plot_tree(dtree, fontsize=5, feature_names=list(X_train.columns), ax=ax, filled=True)
# Out:
# [Text(0.4801432291666667, 0.96875, 'Glucose <= 127.5\nentropy = 0.933\nsamples = 691\nvalue = [450, 241]'),
#  Text(0.205078125, 0.90625, 'Age <= 28.5\nentropy = 0.714\nsamples = 439\nvalue = [353, 86]'),
#  Text(0.08928571428571429, 0.84375, 'BMI <= 30.95\nentropy = 0.404\nsamples = 248\nvalue = [228, 20]'),
#  Text(0.03571428571428571, 0.78125, 'Pregnancies <= 7.5\nentropy = 0.109\nsamples = 138\nvalue = [136, 2]'),
#  Text(0.023809523809523808, 0.71875, 'DiabetesPedigreeFunction <= 0.672\nentropy = 0.062\nsamples = 137\nvalue = [136, 1]'),
#  Text(0.011904761904761904, 0.65625, 'entropy = 0.0\nsamples = 119\nvalue = [119, 0]'),
#  Text(0.03571428571428571, 0.65625, 'DiabetesPedigreeFunction <= 0.686\nentropy = 0.31\nsamples = 18\nvalue = [17, 1]'),
#  Text(0.023809523809523808, 0.59375, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.047619047619047616, 0.59375, 'entropy = 0.0\nsamples = 17\nvalue = [17, 0]'),
#  Text(0.047619047619047616, 0.71875, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.14285714285714285, 0.78125, 'BloodPressure <= 37.0\nentropy = 0.643\nsamples = 110\nvalue = [92, 18]'),
#  Text(0.13095238095238096, 0.71875, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.15476190476190477, 0.71875, 'DiabetesPedigreeFunction <= 0.501\nentropy = 0.605\nsamples = 108\nvalue = [92, 16]'),
#  Text(0.10714285714285714, 0.65625, 'SkinThickness <= 8.0\nentropy = 0.391\nsamples = 65\nvalue = [60, 5]'),
#  Text(0.07142857142857142, 0.59375, 'Glucose <= 109.5\nentropy = 0.954\nsamples = 8\nvalue = [5, 3]'),
#  Text(0.05952380952380952, 0.53125, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.08333333333333333, 0.53125, 'BMI <= 32.45\nentropy = 0.811\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.07142857142857142, 0.46875, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.09523809523809523, 0.46875, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.14285714285714285, 0.59375, 'BMI <= 31.8\nentropy = 0.219\nsamples = 57\nvalue = [55, 2]'),
#  Text(0.13095238095238096, 0.53125, 'Pregnancies <= 2.5\nentropy = 1.0\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.11904761904761904, 0.46875, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.14285714285714285, 0.46875, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.15476190476190477, 0.53125, 'entropy = 0.0\nsamples = 53\nvalue = [53, 0]'),
#  Text(0.20238095238095238, 0.65625, 'BloodPressure <= 61.0\nentropy = 0.82\nsamples = 43\nvalue = [32, 11]'),
#  Text(0.19047619047619047, 0.59375, 'entropy = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.21428571428571427, 0.59375, 'BloodPressure <= 64.5\nentropy = 0.888\nsamples = 36\nvalue = [25, 11]'),
#  Text(0.17857142857142858, 0.53125, 'SkinThickness <= 26.0\nentropy = 0.918\nsamples = 9\nvalue = [3, 6]'),
#  Text(0.16666666666666666, 0.46875, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.19047619047619047, 0.46875, 'BMI <= 36.7\nentropy = 0.592\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.17857142857142858, 0.40625, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.20238095238095238, 0.40625, 'Insulin <= 130.0\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.19047619047619047, 0.34375, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.21428571428571427, 0.34375, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.25, 0.53125, 'Insulin <= 98.0\nentropy = 0.691\nsamples = 27\nvalue = [22, 5]'),
#  Text(0.23809523809523808, 0.46875, 'DiabetesPedigreeFunction <= 0.548\nentropy = 0.852\nsamples = 18\nvalue = [13, 5]'),
#  Text(0.2261904761904762, 0.40625, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.25, 0.40625, 'DiabetesPedigreeFunction <= 0.69\nentropy = 0.696\nsamples = 16\nvalue = [13, 3]'),
#  Text(0.23809523809523808, 0.34375, 'entropy = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.2619047619047619, 0.34375, 'DiabetesPedigreeFunction <= 0.87\nentropy = 0.954\nsamples = 8\nvalue = [5, 3]'),
#  Text(0.25, 0.28125, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.27380952380952384, 0.28125, 'BloodPressure <= 81.0\nentropy = 0.65\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.2619047619047619, 0.21875, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.2857142857142857, 0.21875, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2619047619047619, 0.46875, 'entropy = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.3208705357142857, 0.84375, 'BMI <= 26.35\nentropy = 0.93\nsamples = 191\nvalue = [125, 66]'),
#  Text(0.25, 0.78125, 'BMI <= 9.65\nentropy = 0.31\nsamples = 36\nvalue = [34, 2]'),
#  Text(0.23809523809523808, 0.71875, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.2619047619047619, 0.71875, 'entropy = 0.0\nsamples = 34\nvalue = [34, 0]'),
#  Text(0.39174107142857145, 0.78125, 'Glucose <= 94.5\nentropy = 0.978\nsamples = 155\nvalue = [91, 64]'),
#  Text(0.2857142857142857, 0.71875, 'Glucose <= 28.5\nentropy = 0.571\nsamples = 37\nvalue = [32, 5]'),
#  Text(0.27380952380952384, 0.65625, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.2976190476190476, 0.65625, 'DiabetesPedigreeFunction <= 1.16\nentropy = 0.422\nsamples = 35\nvalue = [32, 3]'),
#  Text(0.2857142857142857, 0.59375, 'Pregnancies <= 9.5\nentropy = 0.323\nsamples = 34\nvalue = [32, 2]'),
#  Text(0.27380952380952384, 0.53125, 'entropy = 0.0\nsamples = 27\nvalue = [27, 0]'),
#  Text(0.2976190476190476, 0.53125, 'SkinThickness <= 27.0\nentropy = 0.863\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.2857142857142857, 0.46875, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.30952380952380953, 0.46875, 'BMI <= 35.1\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.2976190476190476, 0.40625, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.32142857142857145, 0.40625, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.30952380952380953, 0.59375, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.49776785714285715, 0.71875, 'DiabetesPedigreeFunction <= 0.521\nentropy = 1.0\nsamples = 118\nvalue = [59, 59]'),
#  Text(0.43601190476190477, 0.65625, 'DiabetesPedigreeFunction <= 0.426\nentropy = 0.967\nsamples = 84\nvalue = [51, 33]'),
#  Text(0.4017857142857143, 0.59375, 'DiabetesPedigreeFunction <= 0.219\nentropy = 0.993\nsamples = 71\nvalue = [39, 32]'),
#  Text(0.36904761904761907, 0.53125, 'SkinThickness <= 31.0\nentropy = 0.779\nsamples = 26\nvalue = [20, 6]'),
#  Text(0.35714285714285715, 0.46875, 'BMI <= 29.8\nentropy = 0.954\nsamples = 16\nvalue = [10, 6]'),
#  Text(0.34523809523809523, 0.40625, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.36904761904761907, 0.40625, 'BMI <= 34.8\nentropy = 0.994\nsamples = 11\nvalue = [5, 6]'),
#  Text(0.35714285714285715, 0.34375, 'DiabetesPedigreeFunction <= 0.104\nentropy = 0.592\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.34523809523809523, 0.28125, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.36904761904761907, 0.28125, 'entropy = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.38095238095238093, 0.34375, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.38095238095238093, 0.46875, 'entropy = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.43452380952380953, 0.53125, 'BloodPressure <= 67.0\nentropy = 0.982\nsamples = 45\nvalue = [19, 26]'),
#  Text(0.40476190476190477, 0.46875, 'BloodPressure <= 56.0\nentropy = 0.469\nsamples = 10\nvalue = [1, 9]'),
#  Text(0.39285714285714285, 0.40625, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4166666666666667, 0.40625, 'entropy = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.4642857142857143, 0.46875, 'Pregnancies <= 2.5\nentropy = 0.999\nsamples = 35\nvalue = [18, 17]'),
#  Text(0.44047619047619047, 0.40625, 'BloodPressure <= 92.0\nentropy = 0.544\nsamples = 8\nvalue = [1, 7]'),
#  Text(0.42857142857142855, 0.34375, 'entropy = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.4523809523809524, 0.34375, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4880952380952381, 0.40625, 'BloodPressure <= 71.0\nentropy = 0.951\nsamples = 27\nvalue = [17, 10]'),
#  Text(0.47619047619047616, 0.34375, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.5, 0.34375, 'BloodPressure <= 83.0\nentropy = 0.994\nsamples = 22\nvalue = [12, 10]'),
#  Text(0.47619047619047616, 0.28125, 'SkinThickness <= 37.0\nentropy = 0.94\nsamples = 14\nvalue = [5, 9]'),
#  Text(0.4642857142857143, 0.21875, 'BMI <= 38.05\nentropy = 0.684\nsamples = 11\nvalue = [2, 9]'),
#  Text(0.4523809523809524, 0.15625, 'Age <= 55.0\nentropy = 0.469\nsamples = 10\nvalue = [1, 9]'),
#  Text(0.44047619047619047, 0.09375, 'entropy = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.4642857142857143, 0.09375, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.47619047619047616, 0.15625, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4880952380952381, 0.21875, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.5238095238095238, 0.28125, 'DiabetesPedigreeFunction <= 0.243\nentropy = 0.544\nsamples = 8\nvalue = [7, 1]'),
#  Text(0.5119047619047619, 0.21875, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5357142857142857, 0.21875, 'entropy = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.47023809523809523, 0.59375, 'BloodPressure <= 27.0\nentropy = 0.391\nsamples = 13\nvalue = [12, 1]'),
#  Text(0.4583333333333333, 0.53125, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.48214285714285715, 0.53125, 'entropy = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(0.5595238095238095, 0.65625, 'Pregnancies <= 6.5\nentropy = 0.787\nsamples = 34\nvalue = [8, 26]'),
#  Text(0.5476190476190477, 0.59375, 'SkinThickness <= 47.5\nentropy = 0.971\nsamples = 20\nvalue = [8, 12]'),
#  Text(0.5357142857142857, 0.53125, 'Age <= 34.5\nentropy = 0.918\nsamples = 18\nvalue = [6, 12]'),
#  Text(0.5238095238095238, 0.46875, 'Insulin <= 48.0\nentropy = 0.996\nsamples = 13\nvalue = [6, 7]'),
#  Text(0.5119047619047619, 0.40625, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.5357142857142857, 0.40625, 'Age <= 33.5\nentropy = 0.764\nsamples = 9\nvalue = [2, 7]'),
#  Text(0.5238095238095238, 0.34375, 'entropy = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.5476190476190477, 0.34375, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.5476190476190477, 0.46875, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.5595238095238095, 0.53125, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.5714285714285714, 0.59375, 'entropy = 0.0\nsamples = 14\nvalue = [0, 14]'),
#  Text(0.7552083333333334, 0.90625, 'BMI <= 29.95\nentropy = 0.961\nsamples = 252\nvalue = [97, 155]'),
#  Text(0.6369047619047619, 0.84375, 'Glucose <= 145.5\nentropy = 0.903\nsamples = 69\nvalue = [47, 22]'),
#  Text(0.6071428571428571, 0.78125, 'Pregnancies <= 2.5\nentropy = 0.581\nsamples = 36\nvalue = [31, 5]'),
#  Text(0.5952380952380952, 0.71875, 'entropy = 0.0\nsamples = 15\nvalue = [15, 0]'),
#  Text(0.6190476190476191, 0.71875, 'DiabetesPedigreeFunction <= 0.407\nentropy = 0.792\nsamples = 21\nvalue = [16, 5]'),
#  Text(0.6071428571428571, 0.65625, 'SkinThickness <= 28.5\nentropy = 0.961\nsamples = 13\nvalue = [8, 5]'),
#  Text(0.5952380952380952, 0.59375, 'DiabetesPedigreeFunction <= 0.319\nentropy = 0.845\nsamples = 11\nvalue = [8, 3]'),
#  Text(0.5833333333333334, 0.53125, 'Age <= 58.5\nentropy = 0.503\nsamples = 9\nvalue = [8, 1]'),
#  Text(0.5714285714285714, 0.46875, 'entropy = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.5952380952380952, 0.46875, 'BMI <= 25.3\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.5833333333333334, 0.40625, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6071428571428571, 0.40625, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6071428571428571, 0.53125, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6190476190476191, 0.59375, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6309523809523809, 0.65625, 'entropy = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.6666666666666666, 0.78125, 'Age <= 25.5\nentropy = 0.999\nsamples = 33\nvalue = [16, 17]'),
#  Text(0.6547619047619048, 0.71875, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.6785714285714286, 0.71875, 'Age <= 62.0\nentropy = 0.978\nsamples = 29\nvalue = [12, 17]'),
#  Text(0.6666666666666666, 0.65625, 'BMI <= 27.1\nentropy = 0.931\nsamples = 26\nvalue = [9, 17]'),
#  Text(0.6428571428571429, 0.59375, 'Glucose <= 151.0\nentropy = 0.414\nsamples = 12\nvalue = [1, 11]'),
#  Text(0.6309523809523809, 0.53125, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6547619047619048, 0.53125, 'entropy = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(0.6904761904761905, 0.59375, 'BloodPressure <= 82.0\nentropy = 0.985\nsamples = 14\nvalue = [8, 6]'),
#  Text(0.6785714285714286, 0.53125, 'DiabetesPedigreeFunction <= 0.397\nentropy = 0.971\nsamples = 10\nvalue = [4, 6]'),
#  Text(0.6666666666666666, 0.46875, 'Pregnancies <= 6.5\nentropy = 0.592\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.6547619047619048, 0.40625, 'entropy = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.6785714285714286, 0.40625, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6904761904761905, 0.46875, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.7023809523809523, 0.53125, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.6904761904761905, 0.65625, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.8735119047619048, 0.84375, 'Glucose <= 165.5\nentropy = 0.846\nsamples = 183\nvalue = [50, 133]'),
#  Text(0.7946428571428571, 0.78125, 'Age <= 30.5\nentropy = 0.947\nsamples = 123\nvalue = [45, 78]'),
#  Text(0.75, 0.71875, 'BloodPressure <= 61.0\nentropy = 0.994\nsamples = 53\nvalue = [29, 24]'),
#  Text(0.7380952380952381, 0.65625, 'entropy = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.7619047619047619, 0.65625, 'Insulin <= 252.5\nentropy = 0.926\nsamples = 44\nvalue = [29, 15]'),
#  Text(0.75, 0.59375, 'BMI <= 41.7\nentropy = 0.997\nsamples = 32\nvalue = [17, 15]'),
#  Text(0.7261904761904762, 0.53125, 'Glucose <= 154.5\nentropy = 0.943\nsamples = 25\nvalue = [16, 9]'),
#  Text(0.7142857142857143, 0.46875, 'DiabetesPedigreeFunction <= 1.141\nentropy = 0.887\nsamples = 23\nvalue = [16, 7]'),
#  Text(0.7023809523809523, 0.40625, 'DiabetesPedigreeFunction <= 0.57\nentropy = 0.792\nsamples = 21\nvalue = [16, 5]'),
#  Text(0.6904761904761905, 0.34375, 'Pregnancies <= 4.5\nentropy = 0.896\nsamples = 16\nvalue = [11, 5]'),
#  Text(0.6785714285714286, 0.28125, 'BloodPressure <= 73.0\nentropy = 0.75\nsamples = 14\nvalue = [11, 3]'),
#  Text(0.6666666666666666, 0.21875, 'DiabetesPedigreeFunction <= 0.318\nentropy = 0.985\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.6547619047619048, 0.15625, 'SkinThickness <= 39.0\nentropy = 0.722\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.6428571428571429, 0.09375, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.6666666666666666, 0.09375, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6785714285714286, 0.15625, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6904761904761905, 0.21875, 'entropy = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.7023809523809523, 0.28125, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.7142857142857143, 0.34375, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.7261904761904762, 0.40625, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.7380952380952381, 0.46875, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.7738095238095238, 0.53125, 'Pregnancies <= 5.0\nentropy = 0.592\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.7619047619047619, 0.46875, 'entropy = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.7857142857142857, 0.46875, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7738095238095238, 0.59375, 'entropy = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(0.8392857142857143, 0.71875, 'Age <= 33.5\nentropy = 0.776\nsamples = 70\nvalue = [16, 54]'),
#  Text(0.8273809523809523, 0.65625, 'entropy = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(0.8511904761904762, 0.65625, 'BloodPressure <= 91.0\nentropy = 0.837\nsamples = 60\nvalue = [16, 44]'),
#  Text(0.8392857142857143, 0.59375, 'BMI <= 30.7\nentropy = 0.877\nsamples = 54\nvalue = [16, 38]'),
#  Text(0.8273809523809523, 0.53125, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.8511904761904762, 0.53125, 'DiabetesPedigreeFunction <= 0.429\nentropy = 0.911\nsamples = 49\nvalue = [16, 33]'),
#  Text(0.8095238095238095, 0.46875, 'BMI <= 32.45\nentropy = 0.999\nsamples = 23\nvalue = [11, 12]'),
#  Text(0.7976190476190477, 0.40625, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.8214285714285714, 0.40625, 'Glucose <= 130.5\nentropy = 0.949\nsamples = 19\nvalue = [7, 12]'),
#  Text(0.8095238095238095, 0.34375, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.8333333333333334, 0.34375, 'Glucose <= 137.0\nentropy = 0.874\nsamples = 17\nvalue = [5, 12]'),
#  Text(0.8214285714285714, 0.28125, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.8452380952380952, 0.28125, 'Glucose <= 141.5\nentropy = 0.98\nsamples = 12\nvalue = [5, 7]'),
#  Text(0.8333333333333334, 0.21875, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.8571428571428571, 0.21875, 'Pregnancies <= 6.5\nentropy = 0.881\nsamples = 10\nvalue = [3, 7]'),
#  Text(0.8452380952380952, 0.15625, 'Pregnancies <= 4.5\nentropy = 1.0\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.8333333333333334, 0.09375, 'Glucose <= 161.0\nentropy = 0.811\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.8214285714285714, 0.03125, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.8452380952380952, 0.03125, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8571428571428571, 0.09375, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.8690476190476191, 0.15625, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.8928571428571429, 0.46875, 'DiabetesPedigreeFunction <= 0.599\nentropy = 0.706\nsamples = 26\nvalue = [5, 21]'),
#  Text(0.8809523809523809, 0.40625, 'entropy = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.9047619047619048, 0.40625, 'BMI <= 38.3\nentropy = 0.874\nsamples = 17\nvalue = [5, 12]'),
#  Text(0.8809523809523809, 0.34375, 'BloodPressure <= 69.0\nentropy = 0.469\nsamples = 10\nvalue = [1, 9]'),
#  Text(0.8690476190476191, 0.28125, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8928571428571429, 0.28125, 'entropy = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.9285714285714286, 0.34375, 'BloodPressure <= 83.0\nentropy = 0.985\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.9166666666666666, 0.28125, 'DiabetesPedigreeFunction <= 1.368\nentropy = 0.811\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.9047619047619048, 0.21875, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.9285714285714286, 0.21875, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9404761904761905, 0.28125, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.8630952380952381, 0.59375, 'entropy = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.9523809523809523, 0.78125, 'Glucose <= 178.5\nentropy = 0.414\nsamples = 60\nvalue = [5, 55]'),
#  Text(0.9404761904761905, 0.71875, 'entropy = 0.0\nsamples = 21\nvalue = [0, 21]'),
#  Text(0.9642857142857143, 0.71875, 'Pregnancies <= 2.5\nentropy = 0.552\nsamples = 39\nvalue = [5, 34]'),
#  Text(0.9523809523809523, 0.65625, 'entropy = 0.0\nsamples = 16\nvalue = [0, 16]'),
#  Text(0.9761904761904762, 0.65625, 'DiabetesPedigreeFunction <= 1.337\nentropy = 0.755\nsamples = 23\nvalue = [5, 18]'),
#  Text(0.9642857142857143, 0.59375, 'DiabetesPedigreeFunction <= 0.314\nentropy = 0.592\nsamples = 21\nvalue = [3, 18]'),
#  Text(0.9523809523809523, 0.53125, 'Age <= 39.0\nentropy = 0.985\nsamples = 7\nvalue = [3, 4]'),
#  Text(0.9404761904761905, 0.46875, 'SkinThickness <= 28.0\nentropy = 0.811\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.9285714285714286, 0.40625, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.9523809523809523, 0.40625, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9642857142857143, 0.46875, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.9761904761904762, 0.53125, 'entropy = 0.0\nsamples = 14\nvalue = [0, 14]'),
#  Text(0.9880952380952381, 0.59375, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]')]
